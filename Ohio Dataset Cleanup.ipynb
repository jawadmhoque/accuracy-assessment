# %%
import pandas as pd #for working with dataframe
import numpy as np
from scipy import stats, integrate #will help in stats operation in histograms
import matplotlib.pyplot as plt #to plot the PE
import seaborn as sns #nice looking plots
# %matplotlib inline
sns.set(color_codes=True)

# %%
ohio=pd.read_csv('Ohio.csv',encoding='utf-8'
                )

# %%
ohio[ohio['OpeningYear'].isnull()].describe() #what if we were to delete the rows which don't have a forecasted opening year ?
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count         45.000000          0.0            0.0    45.000000
# mean        2006.000000          NaN            NaN  2030.533333
# std            0.953463          NaN            NaN     1.575379
# min         2005.000000          NaN            NaN  2027.000000
# 25%         2005.000000          NaN            NaN  2030.000000
# 50%         2006.000000          NaN            NaN  2030.000000
# 75%         2007.000000          NaN            NaN  2031.000000
# max         2009.000000          NaN            NaN  2035.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount   RecentYrCnt  \
# count      45.000000           21.000000        21.000000     45.000000
# mean    23569.244444         2005.809524     22043.809524  24139.555556
# std     19676.628861            1.123345     18265.783169  21305.441575
# min      4110.000000         2004.000000      3860.000000   3760.000000
# 25%     10389.000000         2006.000000      8830.000000  14240.000000
# 50%     17840.000000         2006.000000     19560.000000  16060.000000
# 75%     25500.000000         2007.000000     24700.000000  23750.000000
# max     90660.000000         2007.000000     67230.000000  77990.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count          12.000000      45.0        45.000000         45.0      45.0
# mean         2010.416667       1.0         2.911111          6.0       1.0
# std             1.240112       0.0         1.040590          0.0       0.0
# min          2009.000000       1.0         1.000000          6.0       1.0
# 25%          2010.000000       1.0         3.000000          6.0       1.0
# 50%          2010.000000       1.0         3.000000          6.0       1.0
# 75%          2010.000000       1.0         3.000000          6.0       1.0
# max          2013.000000       1.0         5.000000          6.0       1.0
#
#        State
# count   45.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %%
ohio=ohio[ohio['OpeningYear'].notnull()] #the dataset that have Opening Year and Opening Year Forecast
#5325 of the 6184 have near actual opening year count and 2923 have recent year count.
#1403 have them actual opening year information.
ohio.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count       6184.000000  6184.000000   6.184000e+03  6184.000000
# mean        2011.047219  2013.533473   2.855940e+04  2031.553687
# std            5.334640     4.082227   3.805500e+04     5.652824
# min         1900.000000  2000.000000   0.000000e+00  2008.000000
# 25%         2008.000000  2010.000000   5.510000e+03  2028.000000
# 50%         2012.000000  2015.000000   1.424000e+04  2032.000000
# 75%         2015.000000  2017.000000   3.500750e+04  2036.000000
# max         2017.000000  2025.000000   1.159100e+06  2050.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count   6.184000e+03         5325.000000      5325.000000    2923.000000
# mean    3.368192e+04         2012.057653     26302.383099   27263.903524
# std     5.609153e+04            3.465601     33277.877396   31226.933010
# min     8.000000e+01         2000.000000         0.000000     200.000000
# 25%     6.400000e+03         2009.000000      4750.000000    6530.000000
# 50%     1.694000e+04         2013.000000     12670.000000   14860.000000
# 75%     4.158250e+04         2015.000000     32890.000000   36480.000000
# max     3.063000e+06         2015.000000    191217.000000  180470.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology     AreaType  \
# count        1403.000000    6184.0      6182.000000       6184.0  4868.000000
# mean         2009.268710       1.0         3.092850          6.0     1.001233
# std             2.704634       0.0         1.497488          0.0     0.049639
# min          2001.000000       1.0         1.000000          6.0     1.000000
# 25%          2008.000000       1.0         1.000000          6.0     1.000000
# 50%          2009.000000       1.0         3.000000          6.0     1.000000
# 75%          2012.000000       1.0         4.000000          6.0     1.000000
# max          2014.000000       1.0         6.000000          6.0     3.000000
#
#         State
# count  6184.0
# mean     41.0
# std       0.0
# min      41.0
# 25%      41.0
# 50%      41.0
# 75%      41.0
# max      41.0

# %%
ohio_completion=ohio[ohio['ActualOpeningYear'].notnull()] #dataframe with rows that have a completion year available
ohio_completion.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count       1403.000000  1403.000000    1403.000000  1403.000000
# mean        2006.570919  2008.704918   29786.931575  2026.083393
# std            2.829901     2.772629   36066.131630     4.733349
# min         1994.000000  2000.000000     250.000000  2008.000000
# 25%         2005.000000  2007.000000    6090.000000  2022.000000
# 50%         2006.000000  2009.000000   14080.000000  2027.000000
# 75%         2009.000000  2011.000000   38155.000000  2030.000000
# max         2013.000000  2015.000000  172870.000000  2038.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count    1403.000000         1403.000000      1403.000000    1353.000000
# mean    35229.135424         2008.461867     27174.944405   26718.632668
# std     41776.570696            2.824732     33920.589199   32891.926947
# min       260.000000         2000.000000       230.000000     230.000000
# 25%      7145.000000         2006.000000      5060.000000    5090.000000
# 50%     17090.000000         2008.000000     12430.000000   12390.000000
# 75%     46050.000000         2010.000000     34520.500000   35350.000000
# max    206500.000000         2015.000000    180470.000000  180470.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count        1403.000000    1403.0      1403.000000       1403.0    1403.0
# mean         2009.268710       1.0         3.025659          6.0       1.0
# std             2.704634       0.0         1.509616          0.0       0.0
# min          2001.000000       1.0         1.000000          6.0       1.0
# 25%          2008.000000       1.0         1.000000          6.0       1.0
# 50%          2009.000000       1.0         3.000000          6.0       1.0
# 75%          2012.000000       1.0         4.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#         State
# count  1403.0
# mean     41.0
# std       0.0
# min      41.0
# 25%      41.0
# 50%      41.0
# 75%      41.0
# max      41.0

# %%
ohio_basic=ohio[ohio['ActualOpeningYear'].isnull()] #dataframe with rows without any completion year. need to take the recent count.
ohio_basic.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count       4781.000000  4781.000000   4.781000e+03  4781.000000
# mean        2012.360803  2014.950429   2.819917e+04  2033.158963
# std            5.182216     3.232589   3.861544e+04     4.837510
# min         1900.000000  2003.000000   0.000000e+00  2015.000000
# 25%         2011.000000  2013.000000   5.320000e+03  2029.000000
# 50%         2013.000000  2015.000000   1.445000e+04  2034.000000
# 75%         2015.000000  2017.000000   3.406000e+04  2037.000000
# max         2017.000000  2025.000000   1.159100e+06  2050.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count   4.781000e+03         3922.000000      3922.000000    1570.000000
# mean    3.322788e+04         2013.343957     25990.245538   27733.808917
# std     5.963994e+04            2.678325     33043.711140   29719.909898
# min     8.000000e+01         2003.000000         0.000000     200.000000
# 25%     6.100000e+03         2013.000000      4639.000000    7882.500000
# 50%     1.680000e+04         2015.000000     12710.000000   16950.000000
# 75%     4.000000e+04         2015.000000     32626.000000   36825.000000
# max     3.063000e+06         2015.000000    191217.000000  163950.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology     AreaType  \
# count                0.0    4781.0      4779.000000       4781.0  3465.000000
# mean                 NaN       1.0         3.112576          6.0     1.001732
# std                  NaN       0.0         1.493493          0.0     0.058832
# min                  NaN       1.0         1.000000          6.0     1.000000
# 25%                  NaN       1.0         1.000000          6.0     1.000000
# 50%                  NaN       1.0         3.000000          6.0     1.000000
# 75%                  NaN       1.0         4.000000          6.0     1.000000
# max                  NaN       1.0         6.000000          6.0     3.000000
#
#         State
# count  4781.0
# mean     41.0
# std       0.0
# min      41.0
# 25%      41.0
# 50%      41.0
# 75%      41.0
# max      41.0

# %%
#working on the ohio_completion
#need to see if NearActualOpeningYear and RecentYear are after the project completion year or not.
#ohio_completion['DiffYr']=ohio_completion.assign[ohio_completion['OpeningYear']-ohio_completion['Year']]
#ohio_completion=ohio_completion.assign(DiffYear=ohio_completion['OpeningYear']-ohio_completion['Year'])
#ohio_completion.describe()

ohio_cleaned=ohio_completion[ohio_completion['OpeningYear']-ohio_completion['ActualOpeningYear']>=0]
#in this dataset we have only the projects that we can compare directly.
ohio_cleaned.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count        815.000000   815.000000     815.000000   815.000000
# mean        2007.161963  2009.182822   26630.057669  2025.689571
# std            2.764868     2.739680   34248.652496     4.918808
# min         2002.000000  2003.000000     250.000000  2014.000000
# 25%         2006.000000  2007.000000    4930.000000  2021.000000
# 50%         2007.000000  2009.000000   11480.000000  2025.000000
# 75%         2009.000000  2011.000000   33340.000000  2030.000000
# max         2013.000000  2015.000000  172000.000000  2035.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count     815.000000          815.000000       815.000000     769.000000
# mean    31403.379141         2008.971779     23789.722699   22730.351105
# std     39777.410925            2.834144     31383.020352   29320.529733
# min       260.000000         2002.000000       250.000000     300.000000
# 25%      5735.000000         2007.000000      4120.000000    4120.000000
# 50%     13090.000000         2009.000000      9960.000000    9810.000000
# 75%     38700.000000         2010.000000     28936.500000   28800.000000
# max    194000.000000         2015.000000    172000.000000  172000.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count         815.000000     815.0       815.000000        815.0     815.0
# mean         2008.969325       1.0         3.072393          6.0       1.0
# std             2.661546       0.0         1.513546          0.0       0.0
# min          2002.000000       1.0         1.000000          6.0       1.0
# 25%          2007.000000       1.0         1.000000          6.0       1.0
# 50%          2009.000000       1.0         3.000000          6.0       1.0
# 75%          2010.000000       1.0         4.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#        State
# count  815.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %%
ohio_scaletype1=ohio_cleaned[ohio_cleaned['OpeningYear']>ohio_cleaned['NearActualOpenYear']]
#the rows here don't have an actual count on the actual opening year. 
#need to compare the recent year count. So scale up the forecast.
ohio_scaletype1.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count        313.000000   313.000000     313.000000   313.000000
# mean        2007.009585  2009.019169   20540.744409  2025.194888
# std            2.654804     2.554461   28783.883444     4.528086
# min         2002.000000  2003.000000     250.000000  2018.000000
# 25%         2006.000000  2007.000000    3980.000000  2022.000000
# 50%         2007.000000  2009.000000    9360.000000  2025.000000
# 75%         2009.000000  2010.000000   20540.000000  2030.000000
# max         2013.000000  2014.000000  147670.000000  2034.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count     313.000000          313.000000       313.000000     305.000000
# mean    23947.667732         2007.738019     18503.201278   18625.016393
# std     32696.783991            2.539759     26580.244367   26264.177176
# min       260.000000         2002.000000       250.000000     370.000000
# 25%      4650.000000         2006.000000      3550.000000    3540.000000
# 50%     11320.000000         2008.000000      8020.000000    8020.000000
# 75%     26240.000000         2009.000000     18410.000000   19070.000000
# max    165690.000000         2013.000000    148550.000000  143380.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count         313.000000     313.0       313.000000        313.0     313.0
# mean         2008.821086       1.0         3.351438          6.0       1.0
# std             2.413889       0.0         1.486415          0.0       0.0
# min          2003.000000       1.0         1.000000          6.0       1.0
# 25%          2007.000000       1.0         3.000000          6.0       1.0
# 50%          2009.000000       1.0         3.000000          6.0       1.0
# 75%          2010.000000       1.0         5.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#        State
# count  313.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %%
ohio_scaletype12=ohio_completion[ohio_completion['OpeningYear']-ohio_completion['ActualOpeningYear']<0]
#Comparing the OpeningYear (forecasted opening year) and ActualOpeningYear again. 
#If the value of the former is smaller, that means we have a forecast for a year that is earlier than the actual year of opening.
#In this case we have to compare the Recent Year Count with the scaled up forecast. 
#so we can append this to the ohio_scale dataframe
ohio_scaletype12.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count        588.000000   588.000000     588.000000   588.000000
# mean        2005.751701  2008.042517   34162.530612  2026.629252
# std            2.714636     2.682500   38041.850037     4.409834
# min         1994.000000  2000.000000     360.000000  2008.000000
# 25%         2004.000000  2006.000000    7730.000000  2025.000000
# 50%         2006.000000  2008.000000   19040.000000  2028.000000
# 75%         2008.000000  2010.000000   45040.000000  2030.000000
# max         2013.000000  2013.000000  172870.000000  2038.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count     588.000000          588.000000       588.000000     584.000000
# mean    40531.841837         2007.755102     31867.045918   31970.325342
# std     43884.573875            2.656590     36666.029644   36439.209963
# min       400.000000         2000.000000       230.000000     230.000000
# 25%      9870.000000         2006.000000      7097.500000    7187.500000
# 50%     22955.000000         2008.000000     16960.000000   17350.000000
# 75%     57175.000000         2009.000000     42467.500000   42347.500000
# max    206500.000000         2014.000000    180470.000000  180470.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count         588.000000     588.0       588.000000        588.0     588.0
# mean         2009.683673       1.0         2.960884          6.0       1.0
# std             2.711312       0.0         1.503035          0.0       0.0
# min          2001.000000       1.0         1.000000          6.0       1.0
# 25%          2008.000000       1.0         1.000000          6.0       1.0
# 50%          2010.000000       1.0         3.000000          6.0       1.0
# 75%          2012.000000       1.0         4.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#        State
# count  588.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %%
ohio_scaletype2=ohio_cleaned[ohio_cleaned['OpeningYear']<ohio_cleaned['NearActualOpenYear']]
ohio_scaletype2.describe()
#need to scale the forecast value up to the near actual year to compare.
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count        211.000000   211.000000     211.000000   211.000000
# mean        2006.663507  2008.488152   27825.184834  2024.573460
# std            2.696655     2.740108   34205.447614     4.660682
# min         2002.000000  2003.000000     550.000000  2016.000000
# 25%         2005.000000  2007.000000    5390.000000  2020.000000
# 50%         2006.000000  2008.000000   10980.000000  2025.000000
# 75%         2008.500000  2009.000000   39800.000000  2028.000000
# max         2013.000000  2014.000000  167040.000000  2034.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count     211.000000          211.000000       211.000000     203.000000
# mean    33441.535545         2009.573460     25299.777251   25055.369458
# std     40183.464282            2.663341     32928.633318   31423.200961
# min       550.000000         2004.000000       446.000000     500.000000
# 25%      6300.000000         2008.000000      4250.000000    4560.000000
# 50%     13090.000000         2009.000000      9746.000000    9800.000000
# 75%     47540.000000         2010.000000     33240.000000   33305.000000
# max    191980.000000         2015.000000    172000.000000  172000.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count         211.000000     211.0       211.000000        211.0     211.0
# mean         2008.369668       1.0         2.962085          6.0       1.0
# std             2.634176       0.0         1.514528          0.0       0.0
# min          2003.000000       1.0         1.000000          6.0       1.0
# 25%          2007.000000       1.0         1.000000          6.0       1.0
# 50%          2008.000000       1.0         3.000000          6.0       1.0
# 75%          2009.000000       1.0         4.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#        State
# count  211.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %%
ohio_adjusted=ohio_cleaned[ohio_cleaned['OpeningYear']==ohio_cleaned['NearActualOpenYear']]
#don't need to scale up or down. can compare the forecast directly with the actual count
ohio_adjusted.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count        291.000000   291.000000     291.000000   291.000000
# mean        2007.687285  2009.862543   32313.161512  2027.030928
# std            2.850616     2.786978   38474.953855     5.210309
# min         2002.000000  2003.000000     590.000000  2014.000000
# 25%         2006.000000  2008.000000    5695.000000  2022.000000
# 50%         2008.000000  2010.000000   14380.000000  2028.000000
# 75%         2010.000000  2013.000000   43950.000000  2032.000000
# max         2013.000000  2015.000000  172000.000000  2035.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count     291.000000          291.000000       291.000000     261.000000
# mean    37944.914089         2009.862543     28380.993127   25719.425287
# std     44897.407239            2.786978     34150.174259   30540.970163
# min       650.000000         2003.000000       280.000000     300.000000
# 25%      6970.000000         2008.000000      5035.000000    4770.000000
# 50%     18030.000000         2010.000000     12700.000000   12850.000000
# 75%     51575.000000         2013.000000     40862.000000   35440.000000
# max    194000.000000         2015.000000    157070.000000  139740.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count         291.000000     291.0       291.000000        291.0     291.0
# mean         2009.563574       1.0         2.852234          6.0       1.0
# std             2.819620       0.0         1.500168          0.0       0.0
# min          2002.000000       1.0         1.000000          6.0       1.0
# 25%          2008.000000       1.0         1.000000          6.0       1.0
# 50%          2009.000000       1.0         3.000000          6.0       1.0
# 75%          2013.000000       1.0         4.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#        State
# count  291.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %%
313+291+211
# Out:
# 815

# %%
ohio_scaletype1=ohio_scaletype1.append(ohio_scaletype12,ignore_index=True)
ohio_scaletype1.describe()
# Out:
#        YearForecastMade  OpeningYear  OYADTForecast   DesignYear  \
# count        901.000000   901.000000     901.000000   901.000000
# mean        2006.188679  2008.381798   29430.433962  2026.130966
# std            2.758406     2.678030   35682.146472     4.500932
# min         1994.000000  2000.000000     250.000000  2008.000000
# 25%         2004.000000  2007.000000    6440.000000  2023.000000
# 50%         2006.000000  2008.000000   14590.000000  2027.000000
# 75%         2008.000000  2010.000000   37190.000000  2030.000000
# max         2013.000000  2014.000000  172870.000000  2038.000000
#
#        DYADTForecast  NearActualOpenYear  NearOpenYrCount    RecentYrCnt  \
# count     901.000000          901.000000       901.000000     889.000000
# mean    34770.635960         2007.749168     27224.556049   27391.788526
# std     41098.940195            2.615193     34092.566918   33883.438766
# min       260.000000         2000.000000       230.000000     230.000000
# 25%      7680.000000         2006.000000      5450.000000    5450.000000
# 50%     17390.000000         2008.000000     13100.000000   13180.000000
# 75%     43470.000000         2009.000000     33820.000000   35350.000000
# max    206500.000000         2014.000000    180470.000000  180470.000000
#
#        ActualOpeningYear  TollType  FunctionalClass  Methodology  AreaType  \
# count         901.000000     901.0       901.000000        901.0     901.0
# mean         2009.384018       1.0         3.096559          6.0       1.0
# std             2.642627       0.0         1.507979          0.0       0.0
# min          2001.000000       1.0         1.000000          6.0       1.0
# 25%          2008.000000       1.0         1.000000          6.0       1.0
# 50%          2010.000000       1.0         3.000000          6.0       1.0
# 75%          2012.000000       1.0         4.000000          6.0       1.0
# max          2014.000000       1.0         6.000000          6.0       1.0
#
#        State
# count  901.0
# mean    41.0
# std      0.0
# min     41.0
# 25%     41.0
# 50%     41.0
# 75%     41.0
# max     41.0

# %% [markdown]
# # Adjust Type 1
# ## Scale up the forecast to recent Year.
# ### use y=mx+c
# $m=\frac{OYADTForecast-DYADTForecast}{OpeningYear-DesignYear}$
#
# $adjusted count=m*(RecentYr-OpeningYear)+OYADTForecast$

# %%
ohio_scaletype1=ohio_scaletype1.assign(m=(ohio_scaletype1['DYADTForecast']-ohio_scaletype1['OYADTForecast'])/
                                            (ohio_scaletype1['DesignYear']-ohio_scaletype1['OpeningYear']))
ohio_scaletype1.head()
# Out:
#      PID  YearForecastMade ForecastMethod  OpeningYear  OYADTForecast  \
# 0  75086              2002             RC       2003.0        27070.0
# 1  20996              2002             RC       2004.0        20540.0
# 2  24316              2002            UNK       2004.0         7280.0
# 3  24316              2002            UNK       2004.0        12170.0
# 4  24316              2002            UNK       2004.0         8540.0
#
#    DesignYear  DYADTForecast Notes  NearActualOpenYear  NearOpenYrCount  \
# 0        2023        34380.0   NaN              2002.0          26700.0
# 1        2024        30400.0   NaN              2003.0          18640.0
# 2        2024         8680.0   NaN              2003.0           6890.0
# 3        2024        14510.0   NaN              2003.0          10410.0
# 4        2024        10180.0   NaN              2003.0           8020.0
#
#   RecentYr  RecentYrCnt  ActualOpeningYear  TollType  FunctionalClass  \
# 0     2008      28740.0             2003.0         1              1.0
# 1     2010      17970.0             2004.0         1              1.0
# 2     2009       6470.0             2004.0         1              3.0
# 3     2009      10150.0             2004.0         1              3.0
# 4     2009       6910.0             2004.0         1              3.0
#
#    Methodology  AreaType ImpromentType  State      m
# 0            6       1.0             1     41  365.5
# 1            6       1.0            12     41  493.0
# 2            6       1.0             1     41   70.0
# 3            6       1.0             1     41  117.0
# 4            6       1.0             1     41   82.0

# %%
ohio_scaletype1=ohio_scaletype1.assign(AdjustedForecast=ohio_scaletype1['m']*(ohio_scaletype1['RecentYr']-ohio_scaletype1['OpeningYear'])
                                      +ohio_scaletype1['OYADTForecast'])
ohio_scaletype1.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     699             with np.errstate(all='ignore'):
# --> 700                 return na_op(lvalues, rvalues)
#     701         except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     681                 mask = notna(x) & notna(y)
# --> 682                 result[mask] = op(x[mask], _values_from_object(y[mask]))
#     683             elif isinstance(x, np.ndarray):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-e12028e5a3ff> in <module>()
# ----> 1 ohio_scaletype1=ohio_scaletype1.assign(AdjustedForecast=ohio_scaletype1['m']*(ohio_scaletype1['RecentYr']-ohio_scaletype1['OpeningYear'])
#       2                                       +ohio_scaletype1['OYADTForecast'])
#       3 ohio_scaletype1.head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     737                 lvalues = lvalues.values
#     738
# --> 739         result = wrap_results(safe_na_op(lvalues, rvalues))
#     740         return construct_result(
#     741             left,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     708                 if is_object_dtype(lvalues):
#     709                     return libalgos.arrmap_object(lvalues,
# --> 710                                                   lambda x: op(x, rvalues))
#     711             raise
#     712
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#     708                 if is_object_dtype(lvalues):
#     709                     return libalgos.arrmap_object(lvalues,
# --> 710                                                   lambda x: op(x, rvalues))
#     711             raise
#     712
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')
