# %% [markdown]
# # Algorithm for Data Processing
#
# 1. Start
# 2. Read .csv file.
# 3. Create separate files for each state.
# 4. Is forecast year=year observed?
# 5. If yes, go to step 6. If no, go to step 9.
# 6. n=number of duplicates in Internal Project ID.
# If Internal Project ID is unavailable, find duplicates by some other method.
# 7. New columns for Percentage Error.
# 8. Percentage Error=1/n*(Forecast-Actual)/Forecast. END
# 9. years=forecast year- year observed.
# 10. growth rate= difference between two projections/number of years in between projections.
# 11. adjusted forecast=forecast AADT*growth rate*years. Go to step 7.

# %%
import pandas as pd
import numpy as np

# %%
flatdata=pd.read_csv("FlatData.csv")
flatdata.head()
# Out:
#                       BriefDescription  Length_miles  FunctionalClass  \
# 0  IR71/US 30 interchange Modification           NaN              1.0
# 1  IR71/US 30 interchange Modification           NaN              1.0
# 2  IR71/US 30 interchange Modification           NaN              3.0
# 3  IR71/US 30 interchange Modification           NaN              3.0
# 4  IR71/US 30 interchange Modification           NaN              1.0
#
#    ImprovementType  State InternalProjectID  \
# 0              NaN   41.0             11378
# 1              NaN   41.0             11378
# 2              NaN   41.0             11378
# 3              NaN   41.0             11378
# 4              NaN   41.0             11378
#
#                 main_ProjectInformation_ProjectID    County  TollType  \
# 0  41-2-11378-IR71/US 30 interchange Modification  Richland         1
# 1  41-2-11378-IR71/US 30 interchange Modification  Richland         1
# 2  41-3-11378-IR71/US 30 interchange Modification  Richland         1
# 3  41-3-11378-IR71/US 30 interchange Modification  Richland         1
# 4  41-4-11378-IR71/US 30 interchange Modification  Richland         1
#
#    ForecastYear  TrafficForecast  ForecastYearType  YearForecastProduced  \
# 0        2000.0            37190               1.0                1994.0
# 1        2020.0            45190               3.0                1994.0
# 2        2000.0            12920               1.0                1994.0
# 3        2020.0            17390               3.0                1994.0
# 4        2000.0            37820               1.0                1994.0
#
#   ForecastMethodology SegmentDescription  main_TrafficForecast_ProjectID  \
# 0                   6     , , RIC7119.08                               2
# 1                   6     , , RIC7119.08                               2
# 2                   6      , , RIC3017.2                               3
# 3                   6      , , RIC3017.2                               3
# 4                   6     , , RIC7118.78                               4
#
#    SegmentID  Year_ofObservation  Count
# 0        NaN                2000  42310
# 1        NaN                2008  39760
# 2        NaN                2000  15780
# 3        NaN                2008  15630
# 4        NaN                2000  42450

# %%
cleaned=flatdata[flatdata['ForecastYear']==flatdata['Year_ofObservation']] #the records where we have counts for the exact year of forecast
cleaned.describe()
# Out:
#        Length_miles  FunctionalClass  ImprovementType        State  \
# count   2213.000000      3019.000000              0.0  5259.000000
# mean       3.153519         3.023186              NaN    32.632820
# std       65.179445         1.327985              NaN    12.539781
# min        0.001000         0.000000              NaN    12.000000
# 25%        0.250000         3.000000              NaN    28.000000
# 50%        0.500000         3.000000              NaN    28.000000
# 75%        1.433000         4.000000              NaN    41.000000
# max     3064.000000         7.000000              NaN    58.000000
#
#           TollType  ForecastYear  TrafficForecast  ForecastYearType  \
# count  5262.000000   5262.000000      5262.000000       3159.000000
# mean      1.003801   1994.792284     25226.256366          1.028490
# std       0.061539    146.205442     26332.191878          0.172009
# min       1.000000      0.000000       110.000000          1.000000
# 25%       1.000000   2000.000000      8100.000000          1.000000
# 50%       1.000000   2008.000000     18000.000000          1.000000
# 75%       1.000000   2013.000000     33237.500000          1.000000
# max       2.000000   2016.000000    231000.000000          3.000000
#
#        YearForecastProduced  main_TrafficForecast_ProjectID     SegmentID  \
# count           5260.000000                     5262.000000  8.510000e+02
# mean            1962.619202                     6007.799886  1.463358e+07
# std              259.446495                     2871.378953  3.299735e+07
# min                0.000000                        2.000000  1.000000e+00
# 25%             1982.000000                     3297.250000  1.000000e+00
# 50%             2005.000000                     7031.500000  1.000000e+00
# 75%             2010.000000                     8398.750000  2.000000e+00
# max             2015.000000                     9663.000000  9.463100e+07
#
#        Year_ofObservation          Count
# count         5262.000000    5262.000000
# mean          1994.792284   26114.856138
# std            146.205442   26825.499696
# min              0.000000       0.000000
# 25%           2000.000000    7488.500000
# 50%           2008.000000   17000.000000
# 75%           2013.000000   36000.000000
# max           2016.000000  224000.000000

# %%
cleaned.groupby('State').count()
# Out:
#        BriefDescription  Length_miles  FunctionalClass  ImprovementType  \
# State
# 12.0                840           653              697                0
# 27.0                  8             8                8                0
# 28.0               2100          1549                0                0
# 41.0               1854             0             1854                0
# 58.0                  0             0              457                0
#
#        InternalProjectID  main_ProjectInformation_ProjectID  County  TollType  \
# State
# 12.0                 697                                840     840       840
# 27.0                   8                                  8       8         8
# 28.0                2100                               2100    1911      2100
# 41.0                1584                               1854    1854      1854
# 58.0                 457                                457     457       457
#
#        ForecastYear  TrafficForecast  ForecastYearType  YearForecastProduced  \
# State
# 12.0            840              840               840                   838
# 27.0              8                8                 8                     8
# 28.0           2100             2100                 0                  2100
# 41.0           1854             1854              1854                  1854
# 58.0            457              457               457                   457
#
#        ForecastMethodology  SegmentDescription  \
# State
# 12.0                   832                 524
# 27.0                     8                   7
# 28.0                  2100                2100
# 41.0                  1854                1854
# 58.0                   457                   0
#
#        main_TrafficForecast_ProjectID  SegmentID  Year_ofObservation  Count
# State
# 12.0                              840        840                 840    840
# 27.0                                8          8                   8      8
# 28.0                             2100          0                2100   2100
# 41.0                             1854          0                1854   1854
# 58.0                              457          0                 457    457

# %%
florida=flatdata[flatdata['State']==12]
michigan=flatdata[flatdata['State']==27]
minnesota=flatdata[flatdata['State']==28]
wisconsin=flatdata[flatdata['State']==58]
ohio=flatdata[flatdata['State']==41]
ohio.head()
# Out:
#                       BriefDescription  Length_miles  FunctionalClass  \
# 0  IR71/US 30 interchange Modification           NaN              1.0
# 1  IR71/US 30 interchange Modification           NaN              1.0
# 2  IR71/US 30 interchange Modification           NaN              3.0
# 3  IR71/US 30 interchange Modification           NaN              3.0
# 4  IR71/US 30 interchange Modification           NaN              1.0
#
#    ImprovementType  State InternalProjectID  \
# 0              NaN   41.0             11378
# 1              NaN   41.0             11378
# 2              NaN   41.0             11378
# 3              NaN   41.0             11378
# 4              NaN   41.0             11378
#
#                 main_ProjectInformation_ProjectID    County  TollType  \
# 0  41-2-11378-IR71/US 30 interchange Modification  Richland         1
# 1  41-2-11378-IR71/US 30 interchange Modification  Richland         1
# 2  41-3-11378-IR71/US 30 interchange Modification  Richland         1
# 3  41-3-11378-IR71/US 30 interchange Modification  Richland         1
# 4  41-4-11378-IR71/US 30 interchange Modification  Richland         1
#
#    ForecastYear  TrafficForecast  ForecastYearType  YearForecastProduced  \
# 0        2000.0            37190               1.0                1994.0
# 1        2020.0            45190               3.0                1994.0
# 2        2000.0            12920               1.0                1994.0
# 3        2020.0            17390               3.0                1994.0
# 4        2000.0            37820               1.0                1994.0
#
#   ForecastMethodology SegmentDescription  main_TrafficForecast_ProjectID  \
# 0                   6     , , RIC7119.08                               2
# 1                   6     , , RIC7119.08                               2
# 2                   6      , , RIC3017.2                               3
# 3                   6      , , RIC3017.2                               3
# 4                   6     , , RIC7118.78                               4
#
#    SegmentID  Year_ofObservation  Count
# 0        NaN                2000  42310
# 1        NaN                2008  39760
# 2        NaN                2000  15780
# 3        NaN                2008  15630
# 4        NaN                2000  42450

# %%
#ohio[ohio['InternalProjectID'].isnull()]
flatdata[flatdata['InternalProjectID'].isnull()].groupby('State').count()
#flatdata[flatdata['Count'].isnull()].groupby('State').count()
# Out:
#        BriefDescription  Length_miles  FunctionalClass  ImprovementType  \
# State
# 12.0                143             0                0                0
# 41.0               1734             0             1736                0
#
#        InternalProjectID  main_ProjectInformation_ProjectID  County  TollType  \
# State
# 12.0                   0                                143     143       143
# 41.0                   0                               1736    1736      1736
#
#        ForecastYear  TrafficForecast  ForecastYearType  YearForecastProduced  \
# State
# 12.0            143              143               143                   143
# 41.0           1736             1736              1736                  1736
#
#        ForecastMethodology  SegmentDescription  \
# State
# 12.0                   143                 143
# 41.0                  1736                1736
#
#        main_TrafficForecast_ProjectID  SegmentID  Year_ofObservation  Count
# State
# 12.0                              143        143                 143    143
# 41.0                             1736          0                1736   1736

# %% [markdown]
# The above describes the number of records in our database that don't have any Internal Project ID. We have to analyse these differently.

# %%
cleaned=ohio[ohio['ForecastYear']==ohio['Year_ofObservation']]
#cleaned.head()

# %% [markdown]
# Looking at the Ohio dataset, we see that in the original excel worksheetthere is a column titled "Physical Works COmpleted On". If the Near Opening Year Count happens before this date, that means the count is taken when the project is not yet done. SO we have to exclude this value.

# %%
new=flatdata[flatdata['ForecastYear']-flatdata['Year_ofObservation']>=0]
#new2=new[new['ForecastYearType']!=3.0]
new2['DiffInYear']=new2['ForecastYear']-new2['Year_ofObservation']
new2=new2[new2['ForecastYearType']!=3.0]
new2['DiffInYear'].describe()
# Out:
# count    9375.000000
# mean        1.605333
# std         3.050037
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        22.000000
# Name: DiffInYear, dtype: float64
