# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("FlatData.csv",encoding='latin1')
df
# Out:
#                                         BriefDescription  Length_miles  \
# 0                    IR71/US 30 interchange Modification           NaN
# 1                    IR71/US 30 interchange Modification           NaN
# 2                    IR71/US 30 interchange Modification           NaN
# 3                    IR71/US 30 interchange Modification           NaN
# 4                    IR71/US 30 interchange Modification           NaN
# 5                    IR71/US 30 interchange Modification           NaN
# 6                    IR71/US 30 interchange Modification           NaN
# 7                    IR71/US 30 interchange Modification           NaN
# 8                                        TUS-0036-15.730           NaN
# 9                                        TUS-0036-15.730           NaN
# 10                                        LOR-0090-13.20           NaN
# 11                                        LOR-0090-13.20           NaN
# ...

# %%
df=df[df['State']==12]
df
# Out:
#                                         BriefDescription  Length_miles  \
# 15046      SR 5/US 1 from 11 Street to Silver Beach Road           NaN
# 15047           SR A1A from Azalea Terrace to (MP 4.030)           NaN
# 15048           SR A1A from Azalea Terrace to (MP 4.030)           NaN
# 15049  SR A1A from Cordova Road to Eastof Eisenhower ...           NaN
# 15050  SR 708 from Old Dixie Highway to 1100 feet eas...           NaN
# 15051  SR 70 Okeechobee Road Virginia Avenue from Eas...           NaN
# 15052  SR 70 Okeechobee Road Virginia Avenue from Eas...           NaN
# 15053  SR 804 from East of Hagen Ranch Road (MP 2.760...           NaN
# 15054  SR 802 East of Congress Avenue (MP 7.200) to W...           NaN
# 15055  SR 811 from Hillsboro Boulevard to SW 18 Stree...           NaN
# 15056  SR 713 St. Lucie County from SR 614/Indrio (MP...           NaN
# 15057                SR 5 from (MP 0.475)  to (MP 0.675)           NaN
# ...

# %%
florida_d4=df[df['InternalProjectID'].isnull()]
florida_d4
# Out:
#                                         BriefDescription  Length_miles  \
# 15046      SR 5/US 1 from 11 Street to Silver Beach Road           NaN
# 15047           SR A1A from Azalea Terrace to (MP 4.030)           NaN
# 15048           SR A1A from Azalea Terrace to (MP 4.030)           NaN
# 15049  SR A1A from Cordova Road to Eastof Eisenhower ...           NaN
# 15050  SR 708 from Old Dixie Highway to 1100 feet eas...           NaN
# 15051  SR 70 Okeechobee Road Virginia Avenue from Eas...           NaN
# 15052  SR 70 Okeechobee Road Virginia Avenue from Eas...           NaN
# 15053  SR 804 from East of Hagen Ranch Road (MP 2.760...           NaN
# 15054  SR 802 East of Congress Avenue (MP 7.200) to W...           NaN
# 15055  SR 811 from Hillsboro Boulevard to SW 18 Stree...           NaN
# 15056  SR 713 St. Lucie County from SR 614/Indrio (MP...           NaN
# 15057                SR 5 from (MP 0.475)  to (MP 0.675)           NaN
# ...

# %%
def find_PID(value): #to clean up the data
    if isinstance(value, str):
        end = value.find('--')
        if end == -1:
            return None
        else:
            start = value.find('-')+1
            return int(value[start:end])

# %%
florida_d4['InternalProjectID'] = florida_d4['main_ProjectInformation_ProjectID'].map(find_PID)
# Out:
# C:\Users\jho337\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
florida_d4
# Out:
#                                         BriefDescription  Length_miles  \
# 15046      SR 5/US 1 from 11 Street to Silver Beach Road           NaN
# 15047           SR A1A from Azalea Terrace to (MP 4.030)           NaN
# 15048           SR A1A from Azalea Terrace to (MP 4.030)           NaN
# 15049  SR A1A from Cordova Road to Eastof Eisenhower ...           NaN
# 15050  SR 708 from Old Dixie Highway to 1100 feet eas...           NaN
# 15051  SR 70 Okeechobee Road Virginia Avenue from Eas...           NaN
# 15052  SR 70 Okeechobee Road Virginia Avenue from Eas...           NaN
# 15053  SR 804 from East of Hagen Ranch Road (MP 2.760...           NaN
# 15054  SR 802 East of Congress Avenue (MP 7.200) to W...           NaN
# 15055  SR 811 from Hillsboro Boulevard to SW 18 Stree...           NaN
# 15056  SR 713 St. Lucie County from SR 614/Indrio (MP...           NaN
# 15057                SR 5 from (MP 0.475)  to (MP 0.675)           NaN
# ...

# %%
florida_d5=df[df['InternalProjectID'].notnull()]
florida_d5
# Out:
#                                         BriefDescription  Length_miles  \
# 15227  Replacement of Medium Level Bridge over Banana...         0.600
# 15228  Replacement of Medium Level Bridge over Banana...         0.600
# 15229  Replacement of Medium Level Bridge over Banana...         0.600
# 15230  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15231  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15232  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15233  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15234  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15235  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15236  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15237  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15238  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# ...

# %%
florida=florida_d5.append(florida_d4)
#flatdata_adjusted2=flatdata_adjusted.append(ohio_adjusted,ignore_index=True)
florida
# Out:
#                                         BriefDescription  Length_miles  \
# 15227  Replacement of Medium Level Bridge over Banana...         0.600
# 15228  Replacement of Medium Level Bridge over Banana...         0.600
# 15229  Replacement of Medium Level Bridge over Banana...         0.600
# 15230  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15231  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15232  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15233  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15234  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15235  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15236  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15237  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15238  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# ...

# %%
florida[florida['InternalProjectID'].notnull()]
# Out:
#                                         BriefDescription  Length_miles  \
# 15227  Replacement of Medium Level Bridge over Banana...         0.600
# 15228  Replacement of Medium Level Bridge over Banana...         0.600
# 15229  Replacement of Medium Level Bridge over Banana...         0.600
# 15230  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15231  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15232  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15233  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15234  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15235  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15236  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15237  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15238  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# ...

# %%
lookup1=pd.read_csv('Florida/lookup05.csv',encoding='latin-1')
lookup2=pd.read_csv('Florida/lookup10.csv',encoding='latin-1')
lookup3=pd.read_csv('Florida/lookup13.csv',encoding='latin-1')

# %%
result1=pd.merge(lookup1,lookup2,how='outer')

# %%
result=pd.merge(result1,lookup3,how='outer')
result
# Out:
#       StationID     2002     2003     2004     2005     2006     2007  \
# 0         10001  33000.0  34000.0  35000.0  32500.0  34000.0  29500.0
# 1         10004  14400.0  18600.0  19400.0  25500.0  19900.0  20500.0
# 2         10007  40000.0  35500.0  39000.0  43500.0  38500.0  36500.0
# 3         10008   7500.0   8700.0   9900.0   9900.0  11200.0  11100.0
# 4         10010  15000.0  13900.0  15400.0  15200.0  16500.0  16400.0
# 5         10014  14395.0      NaN      NaN      NaN      NaN      NaN
# 6         10015  11000.0  11500.0  12500.0  12500.0  12000.0  11000.0
# 7         10016  30500.0  25500.0  29500.0  33500.0  28500.0  28500.0
# 8         10019  15900.0  15400.0  17400.0  16300.0  18000.0  16300.0
# 9         10020      NaN  16000.0      NaN      NaN      NaN      NaN
# 10        10021  17100.0  18100.0  18500.0  20500.0  19100.0  17100.0
# 11        10023   5900.0   5400.0   6300.0   6300.0   7200.0   6500.0
# ...

# %%
result=result[result['StationID']!='Grand Total']

# %%
result['StationID'].astype('int64')
# Out:
# 0         10001
# 1         10004
# 2         10007
# 3         10008
# 4         10010
# 5         10014
# 6         10015
# 7         10016
# 8         10019
# 9         10020
# 10        10021
# 11        10023
# 12        10029
# 13        10030
# 14        10032
# 15        10033
# 16        10034
# 17        10036
# 18        10037
# 19        10038
# 20        10040
# 21        10041
# 22        10042
# 23        10044
# 24        10045
# 25        10048
# 26        10049
# 27        10050
# 28        10051
# 29        10052
#           ...
# 18322    978624
# 18323    978629
# 18324    978630
# 18325    978631
# 18326    978632
# 18327    978637
# 18328    978638
# 18329    978639
# 18330    978640
# 18331    978641
# 18332    978642
# 18333    978643
# 18334    978644
# 18335    978645
# 18336    978646
# 18337    978661
# 18338    978662
# 18339    979005
# 18340    979006
# 18341    979009
# 18342    979010
# 18343    979203
# 18344    979204
# 18345    979205
# ...

# %%
result['StationID']=result['StationID'].astype('float')
result
# Out:
# C:\Users\jho337\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        StationID     2002     2003     2004     2005     2006     2007  \
# 0        10001.0  33000.0  34000.0  35000.0  32500.0  34000.0  29500.0
# 1        10004.0  14400.0  18600.0  19400.0  25500.0  19900.0  20500.0
# 2        10007.0  40000.0  35500.0  39000.0  43500.0  38500.0  36500.0
# 3        10008.0   7500.0   8700.0   9900.0   9900.0  11200.0  11100.0
# 4        10010.0  15000.0  13900.0  15400.0  15200.0  16500.0  16400.0
# 5        10014.0  14395.0      NaN      NaN      NaN      NaN      NaN
# ...

# %%
florida1=pd.read_csv('Florida/florida_PID_Stat.csv',encoding='latin-1')
florida1
# Out:
#      StationID  ForecastYear
# 0     701007.0          2003
# 1     700233.0          2004
# 2     700348.0          2010
# 3     705149.0          2007
# 4     705206.0          2007
# 5     700169.0          2007
# 6     705064.0          2007
# 7     705125.0          2015
# 8     705064.0          2015
# 9     700403.0          2015
# 10    705027.0          2002
# 11    705147.0          2004
# 12    705131.0          2006
# 13    705131.0          2006
# 14    700345.0          2011
# 15    735003.0          2006
# 16    361009.0          2009
# 17    361007.0          2011
# 18    180002.0          2009
# 19    180100.0          2010
# 20    880165.0          2010
# 21    111012.0          2006
# 22    111012.0          2006
# 23    111021.0          2006
# 24    115176.0          2008
# 25    110503.0          2006
# 26    110502.0          2006
# 27    110503.0          2006
# 28    360479.0          2005
# 29    360480.0          2005
# ..         ...           ...
# ...

# %%
result.StationID.describe()
# Out:
# count     18351.000000
# mean     573646.695929
# std      319252.270455
# min       10001.000000
# 25%      175046.500000
# 50%      715019.000000
# 75%      870033.500000
# max      979934.000000
# Name: StationID, dtype: float64

# %%
result2=pd.merge(florida1,result,on='StationID',how='inner')
result2
# Out:
#      StationID  ForecastYear      2002      2003      2004      2005  \
# 0     701007.0          2003   36000.0   32500.0   35000.0   31000.0
# 1     700233.0          2004   31000.0   32000.0   33000.0   33000.0
# 2     700348.0          2010   15000.0   15700.0   17900.0   15700.0
# 3     705149.0          2007   19500.0   18700.0   20000.0   26500.0
# 4     705206.0          2007   15500.0   18500.0   21000.0   26000.0
# 5     700169.0          2007   25500.0   27000.0   28500.0   28500.0
# 6     705064.0          2007   34000.0   34500.0   34500.0   41500.0
# 7     705064.0          2015   34000.0   34500.0   34500.0   41500.0
# 8     705125.0          2015   25500.0   26000.0   27000.0   30500.0
# 9     700403.0          2015   32500.0   34500.0   34000.0   36000.0
# 10    705027.0          2002   52500.0   59000.0   56500.0   60000.0
# 11    705027.0          2011   52500.0   59000.0   56500.0   60000.0
# 12    705147.0          2004   13800.0   15000.0   14100.0   14700.0
# ...

# %%
result3=result2[result2['ForecastYear'].notnull()]

# %%
florida3=pd.read_csv('Florida/florida_PID_Stat2.csv',encoding='latin-1')
florida3
# Out:
#     InternalProjectID  StationID  ForecastYear
# 0            237506-2   701007.0          2003
# 1            237550-1   700233.0          2004
# 2            237565-1   700348.0          2010
# 3            237567-1   705149.0          2007
# 4            237567-1   705206.0          2007
# 5            237576-1   700169.0          2007
# 6            237592-1   705064.0          2007
# 7            237592-2   705125.0          2015
# 8            237592-2   705064.0          2015
# 9            237592-2   700403.0          2015
# 10           237629-1   705027.0          2002
# 11           237632-1   705147.0          2004
# 12           237650-2   705131.0          2006
# 13           237650-2   705131.0          2006
# 14           237650-3   700345.0          2011
# 15           237965-1   735003.0          2006
# 16           411256-3   361009.0          2009
# 17           411256-4   361007.0          2011
# 18           411257-3   180002.0          2009
# ...

# %%
result4=pd.merge(florida3,result,on='StationID',how='inner')
result4
# Out:
#     InternalProjectID  StationID  ForecastYear      2002      2003      2004  \
# 0            237506-2   701007.0          2003   36000.0   32500.0   35000.0
# 1            237550-1   700233.0          2004   31000.0   32000.0   33000.0
# 2            237565-1   700348.0          2010   15000.0   15700.0   17900.0
# 3            237567-1   705149.0          2007   19500.0   18700.0   20000.0
# 4            237567-1   705206.0          2007   15500.0   18500.0   21000.0
# 5            237576-1   700169.0          2007   25500.0   27000.0   28500.0
# 6            237592-1   705064.0          2007   34000.0   34500.0   34500.0
# 7            237592-2   705064.0          2015   34000.0   34500.0   34500.0
# 8            237592-2   705125.0          2015   25500.0   26000.0   27000.0
# 9            237592-2   700403.0          2015   32500.0   34500.0   34000.0
# 10           237629-1   705027.0          2002   52500.0   59000.0   56500.0
# ...

# %%
florida_d5
# Out:
#                                         BriefDescription  Length_miles  \
# 15227  Replacement of Medium Level Bridge over Banana...         0.600
# 15228  Replacement of Medium Level Bridge over Banana...         0.600
# 15229  Replacement of Medium Level Bridge over Banana...         0.600
# 15230  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15231  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15232  S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 15233  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15234  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15235  SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 15236  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15237  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 15238  SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# ...

# %%
florida_d5final=pd.merge(florida_d5,result4)
florida_d5final
# Out:
#                                        BriefDescription  Length_miles  \
# 0     Replacement of Medium Level Bridge over Banana...         0.600
# 1     Replacement of Medium Level Bridge over Banana...         0.600
# 2     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 3     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 4     SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 5     SR 513 Corridor Improvement Project (M.P 1.913...         2.432
# 6     SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 7     SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 8     SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 9     SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 10    SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# 11    SR 501 Resurfacing Project on SR 501 from CR 5...         1.478
# ...

# %%
florida_d5improve=pd.read_csv('Florida/florida_PID_IMP.csv',encoding='latin-1')
florida_d5improve
# Out:
#     InternalProjectID  Improvement Type
# 0            237506-2               1.0
# 1            237550-1               1.0
# 2            237565-1               1.0
# 3            237567-1               1.0
# 4            237567-1               1.0
# 5            237576-1               4.0
# 6            237592-1               4.0
# 7            237592-2               4.0
# 8            237592-2               4.0
# 9            237592-2               4.0
# 10           237629-1               2.0
# 11           237632-1               NaN
# 12           237650-2               1.0
# 13           237650-2               1.0
# 14           237650-3               4.0
# 15           237965-1               4.0
# 16           411256-3               4.0
# 17           411256-4               4.0
# 18           411257-3               4.0
# 19           411257-4               4.0
# 20           411476-1               1.0
# 21           411603-1               1.0
# ...

# %%
florida_d5final=pd.merge(florida_d5final,florida_d5improve,on='InternalProjectID')
florida_d5final.to_csv('Florida/florida_final.csv')

# %%
florida_d5=pd.read_csv('Florida/florida_final.csv')
florida_d5
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...

# %%
florida_d5_2=florida_d5_2.rename(index=str, columns={"2003": "Y2003", "2004": "Y2004",
                                                    "2005"})

# %%
def Year(x): #get the year to compare
    if x.ImprovementType==1:
        year=x.ForecastYear+1
    else:
        year=x.ForecastYear+3
    
    return year

def TrafficCount(x):
    if x.Year==2003:
        Count=x.Y2003
    elif x.Year==2004:
        Count=x.Y2004
    elif x.Year==2005:
        Count=x.Y2005
    elif x.Year==2006:
        Count=x.Y2006
    elif x.Year==2007:
        Count=x.Y2007
    elif x.Year==2008:
        Count=x.Y2008
    elif x.Year==2009:
        Count=x.Y2009
    elif x.Year==2010:
        Count=x.Y2010
    elif x.Year==2011:
        Count=x.Y2011
    elif x.Year==2012:
        Count=x.Y2012
    elif x.Year==2013:
        Count=x.Y2013
    else:
        Count='NA'
    return Count

# %%
florida_d5_2=florida_d5_2(
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...

# %%
florida_d5_2=florida_d5_2.assign(Year2=florida_d5_2.apply(Year,axis=1))

# %%
florida_d5_2
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...

# %%
florida_d5_3
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...

# %%
florida_d5_3=florida_d5_2.assign(Count=florida_d5_2.apply(TrafficCount,axis=1)
                                )

# %%
florida_d5_3.to_csv('florida_d5_3.csv')

# %%
florida_d5_2=pd.read_csv('florida_d5_2.csv',encoding='latin-1')
florida_d5_2
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...

# %%
florida_d5_3=florida_d5_2.assign(Count2=florida_d5_2.apply(TrafficCount,axis=1)
                                )

# %%
florida_d5_3.to_csv('florida_d5.csv')

# %%
florida=pd.read_csv('florida_d5_3.csv',encoding='latin-1')
florida
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...

# %%
def TrafficForecast(x): #adjust the forecast
    if x.Year_ofObservation!=x.ForecastYear:
        m=(x.DYADTForecast-x.OYADTForecast)/(x.DesignYear-x.OpeningYear)
        adjustedforecast=m*(x.Year-x.OpeningYear)+x.OYADTForecast
    else:
        adjustedforecast=x.OYADTForecast
    return adjustedforecast

# %%
florida_rate=pd.read_csv('Florida/florida_PID_Rate.csv',encoding='latin-1')
florida_rate
# Out:
#     InternalProjectID    Rate
# 0            237506-2   125.0
# 1            237550-1  1150.0
# 2            237565-1   455.0
# 3            237567-1   745.0
# 4            237567-1   665.0
# 5            237576-1  1095.0
# 6            237592-1   660.0
# 7            237592-2   400.0
# 8            237592-2   410.0
# 9            237592-2   395.0
# 10           237629-1   550.0
# 11           237632-1  1055.0
# 12           237650-2   735.0
# 13           237650-2   580.0
# 14           237650-3   850.0
# 15           237965-1   320.0
# 16           411256-3   450.0
# 17           411256-4   440.0
# 18           411257-3   585.0
# 19           411257-4   395.0
# 20           411476-1   735.0
# 21           411603-1   940.0
# 22          411603-1A  1340.0
# 23          411603-1A   750.0
# 24           411612-1   230.0
# 25           411613-1   165.0
# 26          411613-1A   220.0
# 27          411613-1A   370.0
# 28           411614-1   375.0
# 29           411614-1   165.0
# ...

# %%
florida3=pd.merge(florida_rate,florida,on='InternalProjectID',how='right')
florida3
# Out:
#        InternalProjectID    Rate  \
# 0               237506-2   125.0
# 1               237506-2   125.0
# 2               237506-2   125.0
# 3               237506-2   125.0
# 4               237506-2   125.0
# 5               237506-2   125.0
# 6               237550-1  1150.0
# 7               237550-1  1150.0
# 8               237550-1  1150.0
# 9               237550-1  1150.0
# 10              237550-1  1150.0
# 11              237550-1  1150.0
# 12              237565-1   455.0
# 13              237565-1   455.0
# 14              237565-1   455.0
# 15              237565-1   455.0
# 16              237565-1   455.0
# 17              237565-1   455.0
# 18              237567-1   745.0
# 19              237567-1   665.0
# 20              237567-1   745.0
# 21              237567-1   665.0
# 22              237567-1   745.0
# 23              237567-1   665.0
# 24              237567-1   745.0
# 25              237567-1   665.0
# 26              237567-1   745.0
# ...

# %%
pd.merge?

# %%
florida
# Out:
#                                         BriefDescription  Length_miles  \
# 0      Replacement of Medium Level Bridge over Banana...         0.600
# 1      Replacement of Medium Level Bridge over Banana...         0.600
# 2      Replacement of Medium Level Bridge over Banana...         0.600
# 3      Replacement of Medium Level Bridge over Banana...         0.600
# 4      Replacement of Medium Level Bridge over Banana...         0.600
# 5      Replacement of Medium Level Bridge over Banana...         0.600
# 6      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 7      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 8      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 9      S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 10     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# 11     S.R. 5/US 1 Resurfacing Project in Brevard Cou...         2.624
# ...
